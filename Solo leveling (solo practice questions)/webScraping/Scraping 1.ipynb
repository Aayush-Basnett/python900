# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.worldometers.info/coronavirus/"
content = requests.get(url).content
soup = BeautifulSoup(content, "html.parser") 
#soup contains all the html content of the url we copied
#print(soup)

# %% [markdown]
# ### Find and findall are beautifulSoap methods and NOT python built in functions

# %%
tbody = soup.find("tbody") #We just want to pull the html data from the table so we pull tbody first

# %%
table_row = tbody.find_all("tr") #We are pulling all the table rows

# %%
table_row[0] #this is now the row that we need so lets look for the one needed
# Out:
# <tr class="total_row_world row_continent" data-continent="North America" style="display: none">
# <td></td>
# <td style="text-align:left;">
# <nobr>North America</nobr>
# </td>
# <td>126,355,533</td>
# <td></td>
# <td>1,630,739</td>
# <td></td>
# <td>122,187,097</td>
# <td></td>
# <td>2,537,697</td>
# <td>6,318</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="North America" style="display:none;">North America</td>
# <!-- 1 Case every X -->
# <td>
# </td>
# <!-- 1 Death every X -->
# <td></td>
# <!-- 1 test every X -->
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>

# %%
table_row[1] #We are looking to start with USA
# Out:
# <tr class="total_row_world row_continent" data-continent="Asia" style="display: none">
# <td></td>
# <td style="text-align:left;">
# <nobr>Asia</nobr>
# </td>
# <td>217,086,605</td>
# <td>+7,178</td>
# <td>1,545,720</td>
# <td>+7</td>
# <td>200,831,884</td>
# <td></td>
# <td>14,709,001</td>
# <td>15,591</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="Asia" style="display:none;">Asia</td>
# <!-- 1 Case every X -->
# <td>
# </td>
# <!-- 1 Death every X -->
# <td></td>
# <!-- 1 test every X -->
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>

# %%
table_row[8] #we've got USA boyz
# Out:
# <tr style="">
# <td style="font-size:12px;color: grey;text-align:center;vertical-align:middle;">1</td>
# <td style="font-weight: bold; font-size:15px; text-align:left;"><a class="mt_a" href="country/us/">USA</a></td>
# <td style="font-weight: bold; text-align:right">106,792,474</td>
# <td style="font-weight: bold; text-align:right;"></td>
# <td style="font-weight: bold; text-align:right;">1,162,701                                </td>
# <td style="font-weight: bold;
#                                     text-align:right;"></td>
# <td style="font-weight: bold; text-align:right">104,777,111</td>
# <td style="font-weight: bold; text-align:right;"></td>
# <td style="text-align:right;font-weight:bold;">852,662</td>
# <td style="font-weight: bold; text-align:right">1,152</td>
# <td style="font-weight: bold; text-align:right">318,969</td>
# <td style="font-weight: bold; text-align:right">3,473</td>
# <td style="font-weight: bold; text-align:right">1,179,105,112</td>
# ...

# %% [markdown]
# # Find_all and filter
# The find_all method and the filter method are similar in that they both allow you to search for elements in a BeautifulSoup object that match a certain criteria. However, they have some differences.
#
# find_all is a BeautifulSoup method that returns a list of all the matching tags and their contents. It allows you to specify a tag name, a list of tag names, a class, an id, or any combination of these as arguments. For example, soup.find_all('p') will return a list of all the `<p>` tags in the soup.
#
# filter is a Python built-in function that takes a function and an iterable as arguments, and returns an iterator containing all the elements of the iterable for which the function returns True. In BeautifulSoup, you can use the filter function to filter the contents of a tag or a list of tags based on some criterion. For example, filter(lambda x: 'spam' in x, soup) will return an iterator containing all the elements of the soup that contain the string 'spam'.
#
# So while they are similar in some ways, they have different use cases. find_all is more commonly used in BeautifulSoup to find elements that match a certain criteria, while filter is more general-purpose and can be used in a wider variety of situations.

# %%
# now we loop through all the rows starting from [8] to get all rows
all_data = []
for row in range(8, len(table_row)): #this loop is to get all the rows
    #we have now entered an individual row
    cd = [] 
    country_data = table_row[row].find_all("td") #this finds all the table data inside of the specific row
 # This loop appends the text content of each table cell to the 'cd' list
    # It also removes some of the unnecessary tags and attributes    
    for item in country_data:
        print(item.text)
        cd.append(item.text)
    all_data.append(cd)
# Out:
# 1
# USA
# 106,792,474
#
# 1,162,701
#
# 104,777,111
#
# 852,662
# 1,152
# 318,969
# 3,473
# 1,179,105,112
# 3,521,764
# 334,805,269
# North America
# 3
# 288
# 0
#
#
# 2,547
# 2
# India
# 44,980,674
#
# 531,770
#
# 44,433,389
#
# 15,515
# N/A
# 31,978
# 378
# 928,487,923
# 660,079
# 1,406,631,776
# Asia
# 31
# 2,645
# 2
#
#
# 11
# 3
# France
# 40,044,973
#
# 166,970
#
# 39,784,462
#
# 93,541
# 869
# 610,586
# 2,546
# 271,490,188
# 4,139,547
# 65,584,518
# Europe
# 2
# 393
# 0
#
#
# 1,426
# 4
# Germany
# 38,417,622
#
# 173,797
#
# 38,217,400
#
# 26,425
# N/A
# 457,987
# 2,072
# 122,332,384
# 1,458,359
# 83,883,596
# Europe
# 2
# 483
# 1
#
#
# 315
# 5
# Brazil
# 37,511,921
#
# 702,116
#
# 36,249,161
#
# 560,644
# N/A
# 174,188
# 3,260
# 63,776,166
# 296,146
# 215,353,593
# South America
# 6
# 307
# 3
#
#
# 2,603
# 6
# Japan
# 33,803,572
#
# 74,694
#
# N/A
# N/A
# N/A
# 83
# 269,169
# 595
# 100,414,883
# 799,578
# 125,584,838
# Asia
# 4
# 1,681
# 1
#
#
# 95,582
# 7
# S. Korea
# ...

# %%
# To make the data organized we use pandas
import pandas as pd
pd.DataFrame(all_data)
# Out:
#       0               1            2  3
# 0      1             USA  106,792,474     \
# 1      2           India   44,980,674
# 2      3          France   40,044,973
# 3      4         Germany   38,417,622
# 4      5          Brazil   37,511,921
# ..   ...             ...          ... ..
# 226  227    Vatican City           29
# 227  228  Western Sahara           10
# 228  229      MS Zaandam            9
# 229  230         Tokelau            5
# 230  231           China      503,302
#
#                                             4  5            6  7        8
# 0    1,162,701                                     104,777,111     852,662  \
# 1      531,770                                      44,433,389      15,515
# 2      166,970                                      39,784,462      93,541
# 3      173,797                                      38,217,400      26,425
# 4      702,116                                      36,249,161     560,644
# ...

# %%
# I only want first column
pd.DataFrame(all_data[0])
# Out:
#                                             0
# 0                                           1
# 1                                         USA
# 2                                 106,792,474
# 3
# 4   1,162,701
# 5
# 6                                 104,777,111
# 7
# 8                                     852,662
# 9                                       1,152
# 10                                    318,969
# 11                                      3,473
# 12                              1,179,105,112
# 13                                  3,521,764
# 14                               334,805,269
# 15                              North America
# 16                                          3
# 17                                        288
# 18                                          0
# 19
# 20
# 21                                      2,547

# %%
# If i only want first 5 colums then,
data = list(map(lambda x: x[1:5], all_data))
#If I want the first row to have custom names rather than default numbers than
columns = ["Country", "TotalCases", "NewCases", "TotalDeaths"]
df = pd.DataFrame(data, columns = columns)
print(df)
# Out:
#             Country   TotalCases NewCases
# 0               USA  106,792,474           \
# 1             India   44,980,674
# 2            France   40,044,973
# 3           Germany   38,417,622
# 4            Brazil   37,511,921
# ..              ...          ...      ...
# 226    Vatican City           29
# 227  Western Sahara           10
# 228      MS Zaandam            9
# 229         Tokelau            5
# 230           China      503,302
#
#                                    TotalDeaths
# 0    1,162,701
# 1      531,770
# 2      166,970
# 3      173,797
# 4      702,116
# ..                                         ...
# 226
# 227          1
# 228          2
# 229
# 230      5,272
#
# [231 rows x 4 columns]
