# %%
a = 1
b = 0.2
c = 0.2 + 4j

# %% [markdown]
# # assigining multiple values to multiple variables
# rather than doing
# a = 1
# b = 0.2
# c = 0.2 + 4j
# we can simply do the following

# %%
a, b, c= 1, 0.2, 0.2 + 4j #a is integer, b is float and c is complex number

# %%
a, b, c
# Out:
# (1, 0.2, (0.2+4j))

# %% [markdown]
# # typechecking

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# complex

# %%
msg = "Hello"
type(msg)
# Out:
# str

# %% [markdown]
# # Assignment -1
# if num1 = 2.5 and num2 = 0.36, swap their values i.e
# num1 = 0.36 and num2 = 2.5

# %%
num1, num2 = 2.5, 0.36

# %%
print(f"initially num1 = {num1}, num2 = {num2}")
num1, num2 = num2, num1
# Out:
# initially num1 = 0.36, num2 = 2.5

# %%
num1 = num1 + num2
num2 = num1 - num2
num1 = num1 - num2
print(f"swapped values using logic are num1={num1} and num2 = {num2}")
# Out:
# swapped values using logic are num1=0.3599999999999999 and num2 = 2.5

# %% [markdown]
# # Assignment -2
# use python intrepretor to calculate the following
# * how many seconds in 42 min and 42 sec?
# * how many miles in 10km ?(1mile = 1.609km)
# * if you run a 10km race in 42 min 42 sec, whats your average pace? (speed : miles in minutes and miles in seconds)

# %%
OneMin = 60
fourtyTwoMin = OneMin * 42
TotalSeconds = fourtyTwoMin + 42
print(f"there are {TotalSeconds} seconds in 42 minutes and 42 seconds")
# Out:
# there are 2562 seconds in 42 minutes and 42 seconds

# %%
OneKM = 1/1.609
tenKM = OneKM * 10
print(f"there are {tenKM} miles in 10km")
# Out:
# there are 6.215040397762586 miles in 10km

# %%
averageSpeed_miles_in_minutes = tenKM/(TotalSeconds/60)
averageSpeed_miles_in_seconds = tenKM/TotalSeconds

print(f"hence, average speed in miles per minute is {averageSpeed_miles_in_minutes}mil/min and in miles per second is {averageSpeed_miles_in_seconds}mil/sec")
# Out:
# hence, average speed in miles per minute is 0.1455512973714891mil/min and in miles per second is 0.0024258549561914852mil/sec

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a, b, c
#
# NameError: name 'a' is not defined

# %%
a, b, c= 3, 4.5, 5 + 3j
a, b, c
# Out:
# (3, 4.5, (5+3j))

# %% [markdown]
# # following is data type validation

# %%
isinstance(a, int) #a integer ho ki hoina check gareko
# Out:
# True

# %%
isinstance(a, complex)
# Out:
# False

# %%
msg = "Call me buddy"
type(msg)
# Out:
# str

# %% [markdown]
# # Assignment 3
# Volume of sphere with radius r is $\frac{4}{3}πr^3$. What is the volume of sphere with radius 5?

# %%
#solution
vol = 4/3*3.14*int(input("declare value of r: "))**3
round_off_value = round(vol, 2)
print(vol, "but round off is ", round_off_value)
# Out:
# declare value of r: 5
# 523.3333333333334 but round off is  523.33

# %%
#you can also import math and do the same
import math
vol = 4/3*math.pi*int(input("declare value of r: "))**3
round_off_value = round(vol, 2)
print(vol, "but round off is ", round_off_value)
# Out:
# declare value of r: 5
# 523.5987755982989 but round off is  523.6

# %% [markdown]
# # Alternate Solutions assignment 1

# %%
num1, num2= 2.5, 0.36
print(f"before num1={num1} and num2={num2}")
num1, num2= 0.36, 2.5
print(f"after num1={num1} and num2={num2}")
# Out:
# before num1=2.5 and num2=0.36
# after num1=0.36 and num2=2.5

# %%
num1, num2= 2.5, 0.36
print(f"before num1={num1} and num2={num2}")
tmp = num1
num1= num2
num2 = tmp
print(f"after num1={num1} and num2={num2}")
# Out:
# before num1=2.5 and num2=0.36
# after num1=0.36 and num2=2.5

# %% [markdown]
# ![Screen%20Shot%202023-04-19%20at%2010.05.40.png](attachment:Screen%20Shot%202023-04-19%20at%2010.05.40.png)
